# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = '/Users/wesleytatum/Desktop/MANA-T/MANA-T_Data/New_Data/AFM/Aggregated/75C_5min_1_2.txt'

# %%
df = np.genfromtxt(filename)
xy, z = df.shape

print (xy, z)
# Out:
# 262144 21

# %%
x = 512
y = 512

# %%
for i in range(z):
    dfslice = np.empty([xy, 1])
    for j in range(xy):
        dfslice[j, 0] = df[j, i]
    plt.figure()
    n, bins, patches = plt.hist(dfslice, bins=100)
# Out:
# /Users/wesleytatum/miniconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
